# %% [markdown]
# <a href="https://colab.research.google.com/github/mikeneko-cat/Prog2kakushin/blob/main/work3_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# turtleもしくはopencvを使ったプログラム作成
#
# ---(内容)---
#
# turtleで画面を放置した時のあれを作る

# %%
#最初に実行!!
# !pip3 install ColabTurtlePlus
from ColabTurtlePlus.Turtle import *
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Put clearscreen() as the first line in a cell (after the import command) to re-run turtle commands in the cell

# %%
import turtle


#スクリーンとturtleの設定
clearscreen()
setup(300,300)
turtle1 = Turtle()
turtle1.shape("turtle")
turtle1.speed(10)
turtle1.pencolor('green')
turtle1.pu()
turtle1.goto(0,0)
turtle1.pd()

#関数の呼び出し
sankaku(turtle1,tims,lenge)
# Out:
# 何回繰り返すか:6
# 一辺の長さ:20
#       <svg width="300" height="300">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
# ...
